# %%
pip install osmnx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import osmnx as ox
import geopandas as gpd

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
city = ox.geocode_to_gdf(query ='Saint Petersburg')

# %%
ox.geocode_to_gdf(query ='Saint Petersburg')
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((30.04334 59.76418, 30.04382 59.76239...   60.090737   59.744148
#
#    bbox_east  bbox_west   place_id  osm_type  osm_id        lat        lon  \
# 0  30.567166  30.043343  150993485  relation  421007  59.938732  30.316229
#
#    class  type  place_rank  importance addresstype              name  \
# 0  place  city          16    0.797927        city  Saint Petersburg
#
#                                         display_name
# 0  Saint Petersburg, Northwestern Federal Distric...

# %%
city.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
city.plot()
# Out:
# <Axes: >

# %%
district = ox.geocode_to_gdf('Красногвардейский район, Saint Petersburg')

# %%
ox.geocode_to_gdf('Красногвардейский район, Saint Petersburg')
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((30.39428 59.92902, 30.39591 59.92574...   60.040946   59.915431
#
#    bbox_east  bbox_west   place_id  osm_type   osm_id        lat        lon  \
# 0  30.566029  30.394281  181803313  relation  1114895  59.978284  30.486584
#
#       class            type  place_rank  importance     addresstype  \
# 0  boundary  administrative          10      0.4387  administrative
#
#                         name  \
# 0  Krasnogvardeysky District
#
#                                         display_name
# 0  Krasnogvardeysky District, Saint Petersburg, N...

# %%
district.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
district.plot ()
# Out:
# <Axes: >

# %%
pip install folium matplotlib mapclassify
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------  10.7/11.0 MB 56.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 49.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    --------- ------------------------------ 10.2/44.5 MB 53.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 18.4/44.5 MB 44.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 24.9/44.5 MB 40.5 MB/s eta 0:00:01
#    ------------------------------- -------- 34.6/44.5 MB 41.5 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.5 MB 42.7 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 39.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
import mapclassify

# %%
city.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
district.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
